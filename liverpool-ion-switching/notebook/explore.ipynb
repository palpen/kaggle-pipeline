# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pwd
# Out:
# '/Users/palermopenano/personal/kaggle-pipeline/liverpool-ion-switching/notebook'

# %%
import pathlib

import pandas as pd
import matplotlib.pyplot as plt

import utils as u

# %%
DATA_PATH = pathlib.Path('/Users/palermopenano/personal/kaggle-pipeline/liverpool-ion-switching/input')

# %%
df = pd.read_csv(DATA_PATH / 'train.csv')
test = pd.read_csv(DATA_PATH / 'test.csv')

# %%
df.open_channels.plot()

# %%
df.set_index('time').reset_index()['time']
# Out:
# 0            0.0001
# 1            0.0002
# 2            0.0003
# 3            0.0004
# 4            0.0005
#              ...
# 4999995    499.9996
# 4999996    499.9997
# 4999997    499.9998
# 4999998    499.9999
# 4999999    500.0000
# Name: time, Length: 5000000, dtype: float64

# %%
df.signal.plot()

# %%
df.shape
# Out:
# (5000000, 3)

# %%
df.iloc[0:10]
# Out:
#      time  signal  open_channels
# 0  0.0001 -2.7600              0
# 1  0.0002 -2.8557              0
# 2  0.0003 -2.4074              0
# 3  0.0004 -3.1404              0
# 4  0.0005 -3.1525              0
# 5  0.0006 -2.6418              0
# 6  0.0007 -2.6993              0
# 7  0.0008 -2.5935              0
# 8  0.0009 -2.6682              0
# 9  0.0010 -2.7586              0

# %% [markdown]
# ### features

# %%
batch_size= 500000
n_trn = df.shape[0]
for i in range(1,int((n_trn / batch_size) + 1)):
    beg = (i-1)*batch_size
    end = i*batch_size -1
    df.loc[beg:end, f'batch'] = int(i)

# %%
df.batch.value_counts()
# Out:
# 1.0     500000
# 10.0    500000
# 9.0     500000
# 8.0     500000
# 7.0     500000
# 6.0     500000
# 5.0     500000
# 4.0     500000
# 3.0     500000
# 2.0     500000
# Name: batch, dtype: int64

# %%
u.print_full(df.loc[999995:1000010, :])
# Out:
#                         time               signal  open_channels                batch
# 999995             99.999600            -2.737600  0                         2.000000
# 999996             99.999700            -1.765000  1                         2.000000
# 999997             99.999800            -2.423900  0                         2.000000
# 999998             99.999900            -1.765000  1                         2.000000
# 999999            100.000000            -2.423900  0                         2.000000
# 1000000           100.000100            -1.719400  1                         3.000000
# 1000001           100.000200            -1.358300  1                         3.000000
# 1000002           100.000300            -1.940300  1                         3.000000
# 1000003           100.000400            -1.078300  1                         3.000000
# 1000004           100.000500            -1.507900  1                         3.000000
# ...

# %%
# n_records = df.shape[0]
# batch_size= 500000
# for i in range(1,int((n_records / batch_size) + 1)):
#     beg = (i-1)*batch_size
#     end = i*batch_size
#     batch = df.iloc[beg:end]
#     print(batch.time.min(), batch.time.max())

#     # Plot rolling mean
#     batch['signal_roll'] = batch.loc[:,'signal'].rolling(10000).mean()
#     batch['open_channels_roll'] = batch.loc[:,'open_channels'].rolling(10000).mean()
#     batch['signal_roll'].plot()
#     batch['open_channels_roll'].plot()
    
#     plt.show()
# Out:
# 0.0001 50.0
# /Users/palermopenano/miniconda3/envs/dsml/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/palermopenano/miniconda3/envs/dsml/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# 50.0001 100.0
# ...

# %% [markdown]
# ### test

# %%
test.shape
# Out:
# (2000000, 2)

# %%
n_records = test.shape[0]
batch_size= 500000
for i in range(1, int((n_records / batch_size) + 1)):
    beg = (i-1)*batch_size
    end = i*batch_size
    batch = test.iloc[beg:end]
    print(batch.time.min(), batch.time.max())

    # Plot rolling mean
    batch['signal_roll'] = batch.loc[:,'signal'].rolling(10000).mean()
    batch['signal_roll'].plot()
    
    plt.show()
# Out:
# 500.0001 550.0
# /Users/palermopenano/miniconda3/envs/dsml/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 550.0001 600.0
# /Users/palermopenano/miniconda3/envs/dsml/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 600.0001 650.0
# ...

# %%
test.head()
# Out:
#        time  signal
# 0  500.0001 -2.6498
# 1  500.0002 -2.8494
# 2  500.0003 -2.8600
# 3  500.0004 -2.4350
# 4  500.0005 -2.6155
